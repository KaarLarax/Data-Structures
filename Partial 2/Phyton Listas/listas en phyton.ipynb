# %%
print("Hello, world")
# Out:
# Hello world

# %%
print("Carlos Alberto Lara Hernandez")
print("Numero de cuenta: 476759")

lista = ['a', 'b', 'd', 'i', 'j']
print("\nElementos de la lista: ")
for i in lista:
    print("Elemento : " + i)

print("\nCantidad de elementos: ")
print(len(lista))
lista.append('e')  # Añade un elemento
print("\nAñadiendo a 'e' ")
lista.append('c')  # Añade un elemento
print("\nAñadiendo a 'c' ")
print("\nElementos de la lista: ")
for i in lista:
    print("Elemento :" + i)

print("Cantidad de elementos: ")
print(len(lista))
lista.sort() # Se ordena la lista
print("\nLista ordenada.")
print("\nElementos de la lista: ")
for i in lista:
    print("Elemento : " + i)

lista.remove('e')  # Elimina un elemento
print("\nElimando a 'e' ")
print("\nElementos de la lista: ")
for i in lista:
    print("Elemento : " + i)
# Out:
# Carlos Alberto Lara Hernandez
# Numero de cuenta: 476759
#
# Elementos de la lista:
# Elemento : a
# Elemento : b
# Elemento : d
# Elemento : i
# Elemento : j
#
# Cantidad de elementos:
# 5
#
# Añadiendo a 'e'
#
# Añadiendo a 'c'
#
# Elementos de la lista:
# Elemento :a
# Elemento :b
# Elemento :d
# Elemento :i
# Elemento :j
# Elemento :e
# Elemento :c
# Cantidad de elementos:
# 7
#
# Lista ordenada.
#
# Elementos de la lista:
# Elemento : a
# Elemento : b
# Elemento : c
# Elemento : d
# Elemento : e
# Elemento : i
# Elemento : j
#
# Elimando a 'e'
#
# Elementos de la lista:
# Elemento : a
# Elemento : b
# Elemento : c
# Elemento : d
# Elemento : i
# Elemento : j
